# %% [markdown]
# <a href="https://colab.research.google.com/github/manukastratta/python-projects/blob/master/Project_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files 
uploaded = files.upload()
# Out:
#      <input type="file" id="files-1175751b-25ee-4bd3-9249-4db39e182979" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1175751b-25ee-4bd3-9249-4db39e182979">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving historical.csv to historical (1).csv
# Saving pass_06_13.csv to pass_06_13 (1).csv
# Saving pass_12_13.csv to pass_12_13 (1).csv

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
dfall = pd.read_csv("historical.csv",index_col="state")
dfall
# Out:
#                       1998  1999  2000  2001  ...  2011  2012  2013       Pop
# state                                         ...
# California             890  1981  2237  2664  ...  3101  3920  4964  38041430
# Texas                  825  1266  1743  2110  ...  3597  3614  3979  26059203
# New York               802  1293  1429  1594  ...  1334  1821  1858  19570261
# Virginia               365   733   677   838  ...  1203  1430  1655   8185867
# Maryland               119   337   480   571  ...  1330  1473  1629   5884563
# New Jersey             387   654   775   912  ...  1120  1235  1582   8864590
# Illinois               193   381   385   412  ...   929  1199  1559  12875255
# Florida                487   755   744   835  ...  1017  1310  1521  19317568
# Georgia                148   571   439   461  ...   884  1037  1261   9919945
# Massachusetts          191   427   408   473  ...   750   913  1067   6646144
# Pennsylvania           235   477   600   637  ...   732   763   883  12763536
# Washington              64    87    94   163  ...   439   542   711   6897012
# Ohio                   186   315   333   455  ...   540   609   697  11544225
# Michigan               109   167   271   309  ...   389   410   577   9883360
# North Carolina         169   335   326   376  ...   412   426   551   9752073
# Connecticut             83   145   153   173  ...   298   436   460   3590347
# Indiana                 21    54    64    77  ...   248   247   391   6537334
# Minnesota               47   156   107   193  ...   260   251   377   5379139
# Colorado                18    85    69   136  ...   223   308   370   5187582
# Kentucky                63   112   105    93  ...   238   280   336   4380415
# Wisconsin               95   209   226   252  ...   183   286   309   5726398
# South Carolina         147   224   306   278  ...   214   276   275   4723723
# Tennessee               49   135   135   136  ...   134   160   251   6456243
# Arizona                 42    51    71    68  ...    89   132   190   6553255
# Oregon                  13     9     5    12  ...    93   112   178   3899353
# Oklahoma                38    76   104   145  ...   113   129   174   3814820
# Arkansas                15    15    46    25  ...   152   146   173   2949131
# Missouri                41    70   168   156  ...   177   212   173   6021988
# Maine                   15    37    55    48  ...    89    65   161   1329192
# Alabama                 46    58    22    27  ...    99    97   126   4822023
# Iowa                    15    36    52    57  ...    72    69   118   3074186
# Utah                    38   100    83    79  ...    41    61   103   2855287
# New Hampshire           11    34    28    37  ...    91   102   101   1320718
# District of Columbia    17    19    47    20  ...    52    61    96    632323
# Hawaii                  33    46    45    65  ...    51    71    83   1392313
# West Virginia            9    31    21    35  ...    38    61    81   1855413
# Delaware                 9    23    41    54  ...    48    61    64    917092
# Rhode Island            12    20    24    48  ...    60    62    61   1050292
# New Mexico               8    17    19    16  ...    42    67    57   2085538
# Nevada                   9    43    34    26  ...    60    56    51   2758931
# Vermont                  7    22    17    19  ...    27    33    47    626011
# Idaho                   16    22    30    33  ...    26    39    47   1595728
# Kansas                  16    17    16    13  ...    25    34    47   2885905
# Nebraska                 4    25    27    12  ...    60    57    46   1855525
# Louisiana               12    40    43    24  ...    34    45    40   4601893
# South Dakota             0     0     2     2  ...     1    25    33    833354
# Alaska                   5    20    21    28  ...    14    13    21    731449
# Montana                  6   ***     3     2  ...     1     3    11   1005141
# North Dakota             5     2     0     1  ...     8    16     9    699628
# Mississippi              0    40    23    20  ...     1     6     1   2984926
# Wyoming                  0    17     6    35  ...     0     1     0    576412
#
# [51 rows x 17 columns]

# %%
df2=pd.read_csv("pass_12_13.csv")
df2
# Out:
#      year         state  ...  black_in_state  hispanic_in_state
# 0    2012       Alabama  ...             NaN                NaN
# 1    2012        Alaska  ...             NaN                NaN
# 2    2012       Arizona  ...             NaN                NaN
# 3    2012      Arkansas  ...             NaN                NaN
# 4    2012    California  ...             NaN                NaN
# ..    ...           ...  ...             ...                ...
# 96   2013        Alaska  ...            4.30                5.5
# 97   2013       Montana  ...            0.67                2.9
# 98   2013  North Dakota  ...            1.08                2.0
# 99   2013   Mississippi  ...           37.30                2.7
# 100  2013       Wyoming  ...            1.29                8.9
#
# [101 rows x 19 columns]

# %%
# Part ONE: dfall

# Pre-processing: Delete unnecessary rows/columns
dfall=dfall.drop(["Pop"],axis=1)
# dfall.info() Get info from dataset to see strange values

# %%
# Find if null values
# Replace weird value by 0
def convert_to_int(x):
  try:
    return int(x)
  except ValueError:
    return 0
    
dfall["1999"]=dfall["1999"].apply(convert_to_int)
dfall.describe()
# Out:
#              1998         1999  ...         2012         2013
# count   51.000000    51.000000  ...    51.000000    51.000000
# mean   120.294118   231.156863  ...   485.921569   579.509804
# std    209.816996   386.616108  ...   811.841754   957.573295
# min      0.000000     0.000000  ...     1.000000     0.000000
# 25%     11.500000    22.500000  ...    61.000000    59.000000
# 50%     38.000000    58.000000  ...   132.000000   174.000000
# 75%    133.000000   269.500000  ...   489.000000   637.000000
# max    890.000000  1981.000000  ...  3920.000000  4964.000000
#
# [8 rows x 16 columns]

# %%
# Print data for California using iloc
# dfall.loc["California"]

# Plot data for California over time
s1=pd.Series(dfall.loc["California"])
s2=pd.Series(dfall.loc["New York"])
s1.plot()
s2.plot()

plt.figure(figsize=(12,5))
plt.xlabel("Number of AP CS Test Takers from 1998-2012")

ax1 = s1.plot(color='blue', grid=True, label='California')
# TODO: add a second axis to view data for different state
ax2 = s2.plot(color='purple', grid=True, label="New York", secondary_y=True)

h1, l1 = ax1.get_legend_handles_labels()
h2, l2 = ax2.get_legend_handles_labels()

plt.legend(h1+h2, l1+l2, loc=2)

plt.show()

# %%
plt.figure(figsize=(30,15))
plt.xlabel("Number of AP CS Test Takers from 1998-2012")

#How to have different colors for all of them?
#colors =plt.cm.jet(np.linspace(0,1,len(data)))
for i in range(len(dfall)):
  s=pd.Series(dfall.iloc[i])
  s.plot(grid=True)

plt.legend(loc='best')
plt.show()

# %%
#Part TWO: df1
df1=pd.read_csv("pass_06_13.csv",index_col="state")
dfNational=df1.iloc[0:8]
df1=df1.drop(["National Data - CS A ","National Data - Calculus AB "],axis=0)

print(dfNational)
print(df1)
# Out:
#                        year  schools_offering  ...     male  male_passed
# state                                          ...
# National Data - CS A   2006               NaN  ...      NaN          NaN
# National Data - CS A   2007               NaN  ...      NaN          NaN
# National Data - CS A   2008            1778.0  ...      NaN          NaN
# National Data - CS A   2009            1879.0  ...      NaN          NaN
# National Data - CS A   2010            2048.0  ...      NaN          NaN
# National Data - CS A   2011            1972.0  ...      NaN          NaN
# National Data - CS A   2012            2103.0  ...      NaN          NaN
# National Data - CS A   2013            2253.0  ...  24070.0      16355.0
#
# [8 rows x 28 columns]
#           year  schools_offering  total  ...  asian_female  male male_passed
# state                                    ...
# Alabama   2006               NaN     20  ...           NaN   NaN         NaN
# Alabama   2007               NaN     27  ...           NaN   NaN         NaN
# Alabama   2008               7.0     41  ...           NaN   NaN         NaN
# Alabama   2009               8.0     24  ...           NaN   NaN         NaN
# Alabama   2010              15.0    104  ...           NaN   NaN         NaN
# ...        ...               ...    ...  ...           ...   ...         ...
# Virginia  2009              83.0    913  ...           NaN   NaN         NaN
# Virginia  2010              98.0   1177  ...           NaN   NaN         NaN
# Virginia  2011              89.0   1203  ...           NaN   NaN         NaN
# Virginia  2012             101.0   1430  ...           NaN   NaN         NaN
# Virginia  2013             110.0   1655  ...           NaN   NaN         NaN
#
# [145 rows x 28 columns]

# %%
dfNational.info()
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8 entries, National Data - CS A  to National Data - CS A
# Data columns (total 28 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   year                    8 non-null      int64
#  1   schools_offering        6 non-null      float64
#  2   total                   8 non-null      int64
#  3   passed                  8 non-null      int64
#  4   female                  8 non-null      int64
#  5   female_passed           8 non-null      object
#  6   black                   8 non-null      int64
#  7   black_passed            8 non-null      object
#  8   black_male              8 non-null      int64
#  9   black_male_passed       8 non-null      object
#  10  black_female            8 non-null      int64
#  11  black_female_passed     8 non-null      object
#  12  hispanic                8 non-null      int64
#  13  hispanic_passed         8 non-null      object
#  14  hispanic_female         8 non-null      int64
#  15  hispanic_female_passed  8 non-null      object
#  16  hispanic_male           8 non-null      float64
#  17  hispanic_male_passed    8 non-null      float64
#  18  white                   8 non-null      float64
#  19  white_passed            8 non-null      float64
#  20  white_male              8 non-null      float64
#  21  white_female            8 non-null      float64
#  22  asian                   8 non-null      float64
#  23  asian_passed            8 non-null      float64
#  24  asian_male              8 non-null      float64
#  25  asian_female            8 non-null      float64
#  26  male                    1 non-null      float64
#  27  male_passed             1 non-null      float64
# dtypes: float64(13), int64(9), object(6)
# memory usage: 1.8+ KB
# <class 'pandas.core.frame.DataFrame'>
# Index: 145 entries, Alabama to Virginia
# Data columns (total 28 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   year                    145 non-null    int64
#  1   schools_offering        108 non-null    float64
#  2   total                   145 non-null    int64
#  3   passed                  145 non-null    int64
#  4   female                  145 non-null    int64
#  5   female_passed           145 non-null    object
#  6   black                   145 non-null    int64
#  7   black_passed            145 non-null    object
#  8   black_male              145 non-null    int64
#  9   black_male_passed       145 non-null    object
#  10  black_female            145 non-null    int64
#  11  black_female_passed     145 non-null    object
#  12  hispanic                145 non-null    int64
#  13  hispanic_passed         145 non-null    object
#  14  hispanic_female         145 non-null    int64
#  15  hispanic_female_passed  145 non-null    object
#  16  hispanic_male           5 non-null      float64
#  17  hispanic_male_passed    5 non-null      float64
#  18  white                   13 non-null     float64
#  19  white_passed            13 non-null     float64
#  20  white_male              5 non-null      float64
#  21  white_female            5 non-null      float64
#  22  asian                   8 non-null      float64
#  23  asian_passed            8 non-null      float64
#  24  asian_male              0 non-null      float64
#  25  asian_female            0 non-null      float64
#  26  male                    0 non-null      float64
#  27  male_passed             0 non-null      float64
# dtypes: float64(13), int64(9), object(6)
# memory usage: 32.9+ KB

# %%
def convert_to_int(x):
  try:
    return int(x)
  except ValueError:
    return 0

dfNationalcol=dfNational.columns.tolist()
df1col=df1.columns.tolist()
for i in range(len(dfNationalcol)):
  dfNational[dfNationalcol[i]]=dfNational[dfNationalcol[i]].apply(convert_to_int)
  df1[df1col[i]]=df1[df1col[i]].apply(convert_to_int)
dfNational.info()
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8 entries, National Data - CS A  to National Data - CS A
# Data columns (total 28 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   year                    8 non-null      int64
#  1   schools_offering        8 non-null      int64
#  2   total                   8 non-null      int64
#  3   passed                  8 non-null      int64
#  4   female                  8 non-null      int64
#  5   female_passed           8 non-null      int64
#  6   black                   8 non-null      int64
#  7   black_passed            8 non-null      int64
#  8   black_male              8 non-null      int64
#  9   black_male_passed       8 non-null      int64
#  10  black_female            8 non-null      int64
#  11  black_female_passed     8 non-null      int64
#  12  hispanic                8 non-null      int64
#  13  hispanic_passed         8 non-null      int64
#  14  hispanic_female         8 non-null      int64
#  15  hispanic_female_passed  8 non-null      int64
#  16  hispanic_male           8 non-null      int64
#  17  hispanic_male_passed    8 non-null      int64
#  18  white                   8 non-null      int64
#  19  white_passed            8 non-null      int64
#  20  white_male              8 non-null      int64
#  21  white_female            8 non-null      int64
#  22  asian                   8 non-null      int64
#  23  asian_passed            8 non-null      int64
#  24  asian_male              8 non-null      int64
#  25  asian_female            8 non-null      int64
#  26  male                    8 non-null      int64
#  27  male_passed             8 non-null      int64
# dtypes: int64(28)
# memory usage: 1.8+ KB
# <class 'pandas.core.frame.DataFrame'>
# Index: 145 entries, Alabama to Virginia
# Data columns (total 28 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   year                    145 non-null    int64
#  1   schools_offering        145 non-null    int64
#  2   total                   145 non-null    int64
#  3   passed                  145 non-null    int64
#  4   female                  145 non-null    int64
#  5   female_passed           145 non-null    int64
#  6   black                   145 non-null    int64
#  7   black_passed            145 non-null    int64
#  8   black_male              145 non-null    int64
#  9   black_male_passed       145 non-null    int64
#  10  black_female            145 non-null    int64
#  11  black_female_passed     145 non-null    int64
#  12  hispanic                145 non-null    int64
#  13  hispanic_passed         145 non-null    int64
#  14  hispanic_female         145 non-null    int64
#  15  hispanic_female_passed  145 non-null    int64
#  16  hispanic_male           145 non-null    int64
#  17  hispanic_male_passed    145 non-null    int64
#  18  white                   145 non-null    int64
#  19  white_passed            145 non-null    int64
#  20  white_male              145 non-null    int64
#  21  white_female            145 non-null    int64
#  22  asian                   145 non-null    int64
#  23  asian_passed            145 non-null    int64
#  24  asian_male              145 non-null    int64
#  25  asian_female            145 non-null    int64
#  26  male                    145 non-null    int64
#  27  male_passed             145 non-null    int64
# dtypes: int64(28)
# memory usage: 32.9+ KB
